# %%
import pandas as pd
import numpy as np
import re
import itertools
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)

# %%
df_main = pd.read_csv(r'data\data_updated.csv')
complete_feature_set = pd.read_csv(r'data\data_feature_set.csv')

# %%
complete_feature_set.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df_main.drop('Unnamed: 0', axis=1, inplace=True)

# %%
top_songs = pd.read_csv('topsongs6months_100_features.csv')

# %%
top_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      100 non-null    int64
#  1   Song            100 non-null    object
#  2   Artist          100 non-null    object
#  3   id              100 non-null    object
#  4   fav_song_score  100 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.0+ KB

# %%
top_songs_upd = top_songs.drop('Unnamed: 0', axis=1)

# %%
top_songs_upd['id'] = [re.split('track:', top_songs_upd['id'][i])[1] for i in range(0, top_songs_upd.shape[0])]

# %%
top_songs_upd.head()
# Out:
#                         Song         Artist                      id  \
# 0              Present Tense      Radiohead  7KHQtpLpoIV3Wfu22YQT8y
# 1                   Waltz #1  Elliott Smith  4SD4ri0Msp6DxgoXKcf6ug
# 2            Stupidity Tries  Elliott Smith  4ggVOqzCnaK9vFXAuvxUeM
# 3                 Decks Dark      Radiohead  4mRSbPLnOm54ttkTYvxxSY
# 4  Jigsaw Falling Into Place      Radiohead  0YJ9FWWHn9EfnN0lHwbzvV
#
#    fav_song_score
# 0        0.800000
# 1        0.601150
# 2        0.333031
# 3        0.317915
# 4        0.295091

# %%
def generate_playlist_feature(complete_feature_set, playlist_df, weight_factor):

    
    complete_feature_set_playlist = complete_feature_set[complete_feature_set['id'].isin(playlist_df['id'].values)]
    complete_feature_set_playlist = complete_feature_set_playlist.merge(playlist_df[['id','fav_song_score']], on = 'id', how = 'inner')
    complete_feature_set_nonplaylist = complete_feature_set[~complete_feature_set['id'].isin(playlist_df['id'].values)]
    
    playlist_feature_set = complete_feature_set_playlist.sort_values('fav_song_score',ascending=False)

    playlist_feature_set['weight'] = playlist_feature_set['fav_song_score'].apply(lambda x: weight_factor ** (-x))
    
    playlist_feature_set_weighted = playlist_feature_set.copy()

    playlist_feature_set_weighted.update(playlist_feature_set_weighted.iloc[:,:-4].mul(playlist_feature_set_weighted.weight,0))
    
    playlist_feature_set_weighted_final = playlist_feature_set_weighted.iloc[:, :-4]
    
    playlist_feature_set_weighted_final['id'] = playlist_feature_set['id']
    
    return playlist_feature_set_weighted_final.sum(axis = 0), complete_feature_set_nonplaylist

# %%
complete_feature_set_playlist_vector, complete_feature_set_nonplaylist = generate_playlist_feature(complete_feature_set, top_songs_upd, 1.1)

# %%
complete_feature_set_playlist_vector
# Out:
# genre|21st_century_classical                                                  0.0
# genre|432hz                                                                   0.0
# genre|_hip_hop                                                                0.0
# genre|a_cappella                                                              0.0
# genre|abstract                                                                0.0
#                                                       ...
# year|2016                                                                     0.0
# year|2017                                                                     0.0
# year|2018                                                                     0.0
# year|2019                                                                0.496981
# id                              4SD4ri0Msp6DxgoXKcf6ug5AMrnF761nziCWUfjBgRUI6Y...
# Length: 3050, dtype: object

# %%
complete_feature_set_nonplaylist.drop(list(set(complete_feature_set_nonplaylist.columns).difference(set(complete_feature_set_playlist_vector.index))), axis=1, inplace=True)

# %%
client_id = 'client id'
client_secret = 'secret id'
sp = spotipy.Spotify(client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %%
def generate_playlist_recos(df, features, nonplaylist_features):
    non_playlist_df = df[df['id'].isin(nonplaylist_features['id'].values)]
    non_playlist_df['sim'] = cosine_similarity(nonplaylist_features.drop('id', axis = 1).values, features.drop(labels='id').values.reshape(1, -1))[:,0]
    non_playlist_df_top_40 = non_playlist_df.sort_values('sim',ascending = False).head(50)
    non_playlist_df_top_40['url'] = non_playlist_df_top_40['id'].apply(lambda x: sp.track(x)['album']['images'][1]['url'])
    return non_playlist_df_top_40

# %%
top50_recommendations = generate_playlist_recos(df_main, complete_feature_set_playlist_vector, complete_feature_set_nonplaylist)

# %%
top50_recommendations_upd = top50_recommendations.loc[:, ['id', 'name', 'artists', 'year', 'url']]

# %%
top50_recommendations_upd.reset_index(drop=True, inplace=True)

# %%
top50_recommendations_upd
# Out:
#                         id                                name  \
# 0   3pwj90XGAD6I0jO3q6fkCx                        Baby Britain
# 1   4xfAVJL8R7mVYbDk8a9xOY        Somebody That I Used To Know
# 2   3pM7gfel0ho7yVJw4KK5Eq                    Independence Day
# 3   4zetUxeSCCDwrr1jJT0SuD                         Miss Misery
# 4   44xqX8IBgEkis0PZrKRXp1                          Bled White
# 5   6Hlt4S0nm1URyqM0WLlQzY                        Easy Way Out
# 6   2c7AnyxXkbemyTEpzprQVx              Bottle Up And Explode!
# 7   7AG284RTvcDG9uHt1NQIbu                         Oh Well, OK
# 8   1cYudm5fk5igcsjroJKmFw                   Tomorrow Tomorrow
# 9   1Q0sk7b7PAGjgC3R5zyuWt                            Pitseleh
# 10  3nkdVXnH4xC6f3YZS0C8pC        Everything Reminds Me Of Her
# 11  17dXDRfCPqxAG3xt9g5Kpe                  Christian Brothers
# 12  1aMFot4xU2SHSaojGARIYu                     St. Ides Heaven
# 13  6WuRo5MdVrpKCl6lkKIAlp                   Needle In The Hay
# 14  4xFNWqI3kQ34kNKMplWsk2                     The Biggest Lie
# 15  6d30fp8FovPTaeEiWb9i0y                      Southern Belle
# 16  4IlHNGyLShupQ4ffnrtADn                           Satellite
# 17  7txWpzNPNQmIEakeGkqZWo                       Alphabet Town
# 18  5I82Gy3FcoPGP4rzYbXADt                    Junk Bond Trader
# 19  0nUPuUnqVLOZFayUzxi1JG                          Clementine
# 20  75l3rO9pLGAas7P4O22RDE       The White Lady Loves You More
# 21  6mfy4Q8P3fVXMeuD5d19oi               Ballad Of Big Nothing
# 22  5KmMMmc1pXL5lL4HlR9Srz                       Sweet Adeline
# 23  2f0KFqF9B2oKOx0NBVTaXv                     A Fond Farewell
# 24  3c1EHob1Rp5p1P37YERSr6                             Alameda
# 25  5YoR2agiVdBpuAuW9PvgKD                            Twilight
# 26  4ePiNo6s2nZdxP26A0ATau                        Speed Trials
# 27  3XtkcPHbYX0BImTQLlbSVN                             Say Yes
# 28  09xUNc3vKdOmH74jWIYfAm                          No Name #1
# 29  2Fw1fhTZwYacC0tGqMbjaE         Miss Misery (Early Version)
# 30  3aU2ui8JQOtmgHYH0g1qFL           Happiness/The Gondola Man
# 31  0Fr9IKeo8GlR3JHRF3ntxC                         Rose Parade
# 32  7MSuEJUiHDa28DyCCZkobJ                          Condor Ave
# 33  03Nc7jSUCH99Uy6kcJMSxW                          No Name #2
# 34  3IQApXKUun0iHHtpsvI7xL                 I Didn't Understand
# 35  7GDciQOihRs8nQFEFOrc5K                        Roman Candle
# 36  47ErYu7aQQuHjzM1IEnHML                      Coast to Coast
# 37  4q43oDutQO54nWHxf6vlMI                       No Name No. 5
# 38  0VJ0DLSA4d2pYJcTEe2rrV                Pretty (Ugly Before)
# 39  32gMbrYoS2qIA54JmZ9TFn  Kiwi Maddog 20/20 (version 2 of 2)
# 40  56glzc2mZUIJwKsEjKqY8b                     Coming Up Roses
# 41  4JosyubgIpErAsvMKwph8n                                 Bye
# 42  39GFqAvg1Bvabc4syFawmY                      Let's Get Lost
# 43  2zzJVFSgRcu1ClWtYqlad8                           Last Call
# 44  17BBWuaTH2soxiyIaV6l5r                      Pictures Of Me
# 45  53q5m5Bpkr1Pin7mPKQxMi                             2:45 AM
# 46  2uwN3PDudlRkAKE3wA0OqJ                             Angeles
# 47  5xmqzcBqw4c0c5gcDHthDO                          No Name #3
# 48  6tTruZoKILnwqQrBhJ7o3I                      Punch And Judy
# 49  5F7WnD1XLfvyqglClI5fL7                        Cupids Trick
#
#               artists  year                                                url
# 0   ['Elliott Smith']  1998  https://i.scdn.co/image/ab67616d00001e02cdf1be...
# 1   ['Elliott Smith']  2000  https://i.scdn.co/image/ab67616d00001e02169a23...
# 2   ['Elliott Smith']  1998  https://i.scdn.co/image/ab67616d00001e02cdf1be...
# 3   ['Elliott Smith']  1998  https://i.scdn.co/image/ab67616d00001e02e35493...
# 4   ['Elliott Smith']  1998  https://i.scdn.co/image/ab67616d00001e02cdf1be...
# 5   ['Elliott Smith']  2000  https://i.scdn.co/image/ab67616d00001e02169a23...
# 6   ['Elliott Smith']  1998  https://i.scdn.co/image/ab67616d00001e02cdf1be...
# 7   ['Elliott Smith']  1998  https://i.scdn.co/image/ab67616d00001e02cdf1be...
# 8   ['Elliott Smith']  1998  https://i.scdn.co/image/ab67616d00001e02cdf1be...
# 9   ['Elliott Smith']  1998  https://i.scdn.co/image/ab67616d00001e02cdf1be...
# 10  ['Elliott Smith']  2000  https://i.scdn.co/image/ab67616d00001e02169a23...
# 11  ['Elliott Smith']  1995  https://i.scdn.co/image/ab67616d00001e02b6e316...
# 12  ['Elliott Smith']  1995  https://i.scdn.co/image/ab67616d00001e02b6e316...
# 13  ['Elliott Smith']  1995  https://i.scdn.co/image/ab67616d00001e02b6e316...
# 14  ['Elliott Smith']  1995  https://i.scdn.co/image/ab67616d00001e02b6e316...
# 15  ['Elliott Smith']  1995  https://i.scdn.co/image/ab67616d00001e02b6e316...
# 16  ['Elliott Smith']  1995  https://i.scdn.co/image/ab67616d00001e02b6e316...
# 17  ['Elliott Smith']  1995  https://i.scdn.co/image/ab67616d00001e02b6e316...
# 18  ['Elliott Smith']  2000  https://i.scdn.co/image/ab67616d00001e02169a23...
# 19  ['Elliott Smith']  1995  https://i.scdn.co/image/ab67616d00001e02b6e316...
# 20  ['Elliott Smith']  1995  https://i.scdn.co/image/ab67616d00001e02b6e316...
# 21  ['Elliott Smith']  1997  https://i.scdn.co/image/ab67616d00001e0236e934...
# 22  ['Elliott Smith']  1998  https://i.scdn.co/image/ab67616d00001e02cdf1be...
# 23  ['Elliott Smith']  2004  https://i.scdn.co/image/ab67616d00001e029d8576...
# 24  ['Elliott Smith']  1997  https://i.scdn.co/image/ab67616d00001e0236e934...
# 25  ['Elliott Smith']  2004  https://i.scdn.co/image/ab67616d00001e029d8576...
# 26  ['Elliott Smith']  1997  https://i.scdn.co/image/ab67616d00001e0236e934...
# 27  ['Elliott Smith']  1997  https://i.scdn.co/image/ab67616d00001e0236e934...
# 28  ['Elliott Smith']  1994  https://i.scdn.co/image/ab67616d00001e0256eea8...
# 29  ['Elliott Smith']  2007  https://i.scdn.co/image/ab67616d00001e02ddf56f...
# 30  ['Elliott Smith']  2000  https://i.scdn.co/image/ab67616d00001e02169a23...
# 31  ['Elliott Smith']  1997  https://i.scdn.co/image/ab67616d00001e02021e2d...
# 32  ['Elliott Smith']  1994  https://i.scdn.co/image/ab67616d00001e0256eea8...
# 33  ['Elliott Smith']  1994  https://i.scdn.co/image/ab67616d00001e0256eea8...
# 34  ['Elliott Smith']  1998  https://i.scdn.co/image/ab67616d00001e02cdf1be...
# 35  ['Elliott Smith']  1994  https://i.scdn.co/image/ab67616d00001e0256eea8...
# 36  ['Elliott Smith']  2004  https://i.scdn.co/image/ab67616d00001e029d8576...
# 37  ['Elliott Smith']  1997  https://i.scdn.co/image/ab67616d00001e0236e934...
# 38  ['Elliott Smith']  2004  https://i.scdn.co/image/ab67616d00001e029d8576...
# 39  ['Elliott Smith']  1994  https://i.scdn.co/image/ab67616d00001e0256eea8...
# 40  ['Elliott Smith']  1995  https://i.scdn.co/image/ab67616d00001e02b6e316...
# 41  ['Elliott Smith']  2000  https://i.scdn.co/image/ab67616d00001e02169a23...
# 42  ['Elliott Smith']  2004  https://i.scdn.co/image/ab67616d00001e029d8576...
# 43  ['Elliott Smith']  1994  https://i.scdn.co/image/ab67616d00001e0256eea8...
# 44  ['Elliott Smith']  1997  https://i.scdn.co/image/ab67616d00001e0236e934...
# 45  ['Elliott Smith']  1997  https://i.scdn.co/image/ab67616d00001e0236e934...
# 46  ['Elliott Smith']  1997  https://i.scdn.co/image/ab67616d00001e0236e934...
# 47  ['Elliott Smith']  1994  https://i.scdn.co/image/ab67616d00001e0256eea8...
# 48  ['Elliott Smith']  1997  https://i.scdn.co/image/ab67616d00001e0236e934...
# 49  ['Elliott Smith']  1997  https://i.scdn.co/image/ab67616d00001e0236e934...
